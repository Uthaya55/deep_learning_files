# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
import numpy as np

# %%
from matplotlib import pyplot as pt

# %%
tf.keras.datasets
# Out:
# <module 'keras.api.datasets' from '/usr/local/lib/python3.11/dist-packages/keras/api/datasets/__init__.py'>

# %%
from keras.datasets import cifar10

# %%
d1=cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
(trainX,trainY),(testX,testY)=cifar10.load_data()

# %%
trainX.shape
# Out:
# (50000, 32, 32, 3)

# %%
testX.shape
# Out:
# (10000, 32, 32, 3)

# %%
'''for i in range(6):
  pt.subplot(230+1+i)'''
pt.imshow(trainX[40000])
pt.show()

# %%
from keras.datasets import mnist

# %%
(trainX,trainY),(testX,testY)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
trainX.shape
# Out:
# (60000, 28, 28)

# %%
testX.shape
# Out:
# (10000, 28, 28)

# %%
pt.imshow(trainX[40000])
pt.show()

# %%
from keras.datasets import fashion_mnist

# %%
(trainX,trainY),(testX,testY)=fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
trainX.shape
# Out:
# (60000, 28, 28)

# %%
testX.shape
# Out:
# (10000, 28, 28)

# %%
pt.imshow(trainX[40000])
pt.show()

# %%
text_data=np.array([["hi"],["hi shiyam"]])

# %%
text_data
# Out:
# array([['hi'],
#        ['hi shiyam']], dtype='<U9')

# %%
from tensorflow.keras.layers import TextVectorization

# %%
vecterizer=TextVectorization(output_mode="int")

# %%
vecterizer.adapt(text_data)

# %%
vector_data=vecterizer(text_data)

# %%
vector_data
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int64, numpy=
# array([[2, 0],
#        [2, 3]])>

# %%
vecterizer.get_vocabulary()
# Out:
# ['', '[UNK]', np.str_('hi'), np.str_('shiyam')]
